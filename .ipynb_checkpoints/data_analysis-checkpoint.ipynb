# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
from plotnine import *

# %%
#posts = dd.read_csv("Complete-Posts-Compressed/*.tar.xz", compression="xz")
posts = dd.read_csv("Complete-Posts/*.csv")

# %%
#posts.astype(float).corr().compute()#["isAnswered"]

# %%
#posts.astype(float).describe().compute()

# %% [markdown]
# ## Warning: in memory computations

# %%
df = posts.compute()

# %%
## TODO remove outliers
df = df.loc[df["AnswerCount"]<25]
df = df.loc[df["BlocksCount"]<10]
df = df.loc[df["LinksCount"]<10]

# %%
df.describe()
# Out:
#               Score     ViewCount     WordCount    LinksCount   BlocksCount  \
# count  1.641965e+07  1.641965e+07  1.641965e+07  1.641965e+07  1.641965e+07
# mean   1.920363e+00  2.109085e+03  8.911707e+01  2.949882e-01  1.999033e+00
# std    2.620062e+01  1.443399e+04  6.360844e+01  7.007091e-01  1.984313e+00
# min   -1.850000e+02  1.000000e+00  2.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  7.700000e+01  4.800000e+01  0.000000e+00  1.000000e+00
# 50%    0.000000e+00  2.720000e+02  7.400000e+01  0.000000e+00  1.000000e+00
# 75%    1.000000e+00  9.620000e+02  1.110000e+02  0.000000e+00  3.000000e+00
# max    2.225200e+04  3.913031e+06  8.020000e+03  9.000000e+00  9.000000e+00
#
#        TitleWordsCount   AnswerCount  CommentCount  tagsAggregate
# count     1.641965e+07  1.641965e+07  1.641965e+07   1.641965e+07
# mean      8.576060e+00  1.536222e+00  1.969255e+00   9.488850e+05
# std       3.603330e+00  1.366787e+00  2.661569e+00   8.476725e+05
# min       1.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       6.000000e+00  1.000000e+00  0.000000e+00   1.692600e+05
# 50%       8.000000e+00  1.000000e+00  1.000000e+00   8.844655e+05
# 75%       1.100000e+01  2.000000e+00  3.000000e+00   1.487235e+06
# max       4.500000e+01  2.400000e+01  1.090000e+02   6.680300e+06

# %%
df.corr()
# Out:
#                     Score  ViewCount  WordCount  LinksCount  BlocksCount  \
# Score            1.000000   0.479918  -0.000210    0.006207     0.002353
# ViewCount        0.479918   1.000000  -0.020764   -0.006160    -0.005261
# WordCount       -0.000210  -0.020764   1.000000    0.186468     0.141789
# LinksCount       0.006207  -0.006160   0.186468    1.000000     0.027251
# BlocksCount      0.002353  -0.005261   0.141789    0.027251     1.000000
# TitleWordsCount -0.000917  -0.007807   0.080503    0.012303    -0.005675
# AnswerCount      0.182987   0.347396  -0.040102   -0.045883    -0.000874
# CommentCount     0.007655  -0.000663   0.060552    0.014099     0.105541
# bounty           0.038449   0.016084   0.071942    0.067407     0.031113
# tagsAggregate   -0.005348   0.003601   0.001363    0.011735     0.082253
# isAnswered       0.035820   0.067257  -0.016104   -0.008990     0.072871
#
#                  TitleWordsCount  AnswerCount  CommentCount    bounty  \
# Score                  -0.000917     0.182987      0.007655  0.038449
# ViewCount              -0.007807     0.347396     -0.000663  0.016084
# WordCount               0.080503    -0.040102      0.060552  0.071942
# LinksCount              0.012303    -0.045883      0.014099  0.067407
# BlocksCount            -0.005675    -0.000874      0.105541  0.031113
# TitleWordsCount         1.000000    -0.017552     -0.004141  0.006800
# AnswerCount            -0.017552     1.000000     -0.005900  0.071757
# CommentCount           -0.004141    -0.005900      1.000000  0.051184
# bounty                  0.006800     0.071757      0.051184  1.000000
# tagsAggregate           0.003319     0.075937      0.123745 -0.009987
# isAnswered             -0.016378     0.269489     -0.073088  0.009253
#
#                  tagsAggregate  isAnswered
# Score                -0.005348    0.035820
# ViewCount             0.003601    0.067257
# WordCount             0.001363   -0.016104
# LinksCount            0.011735   -0.008990
# BlocksCount           0.082253    0.072871
# TitleWordsCount       0.003319   -0.016378
# AnswerCount           0.075937    0.269489
# CommentCount          0.123745   -0.073088
# bounty               -0.009987    0.009253
# tagsAggregate         1.000000    0.028121
# isAnswered            0.028121    1.000000

# %% [markdown]
# # Simple plots

# %%
# plot random sample of 1000 points 
temp_df = df.sample(n=10000)
for column in posts.compute():
    if column != "isAnswered":
        print(column)
        plot = ggplot(temp_df, aes(x="isAnswered", y=column))
        plot += geom_jitter(size=0.1)
        print(plot)
# Out:
# Score
# <ggplot: (-9223363271044502917)>
# ViewCount
# <ggplot: (8765813970240)>
# WordCount
# <ggplot: (-9223363271394388094)>
# LinksCount
# <ggplot: (-9223363271040812235)>
# BlocksCount
# <ggplot: (-9223363271044609255)>
# TitleWordsCount
# <ggplot: (8765776997994)>
# AnswerCount
# <ggplot: (-9223363271077838199)>
# CommentCount
# <ggplot: (8765776910905)>
# bounty
# <ggplot: (8765776744214)>
# tagsAggregate
# <ggplot: (8765776718845)>

# %% [markdown]
# # More plots

# %%
#do not re-run this
plot = ggplot(df, aes(x="isAnswered"))
plot += geom_bar()
plot
# Out:
# <ggplot: (-9223363271044498102)>

# %%
plot = ggplot(temp_df, aes(x="Score", y="ViewCount", color="isAnswered"))
plot += geom_jitter(size=0.1)
plot += scale_y_log10()
plot
# Out:
# <ggplot: (-9223363271044530053)>

# %%
plot = ggplot(temp_df, aes(x="Score", y="ViewCount", color="isAnswered"))
plot += xlim(-5,10)
plot += ylim(0,10000)
plot += geom_jitter(size=0.1)
plot
# Out:
# /usr/lib64/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /usr/lib64/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /home/wojtek/.local/lib/python3.6/site-packages/plotnine/layer.py:449: UserWarning: geom_jitter : Removed 4974 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (8765747673506)>

# %%
plot = ggplot(temp_df, aes(x="Score", y="AnswerCount", color="isAnswered"))
plot += geom_jitter(size=0.1)
plot
# Out:
# <ggplot: (8765760039807)>

# %%
#do not re-run this
plot = ggplot(df.loc[df["AnswerCount"]<10], aes(x="AnswerCount"))
plot += geom_bar()
plot += scale_x_continuous(breaks=range(0,10,2))
plot
# Out:
# <ggplot: (-9223363271094659184)>

# %%
# TODO caluclate number of posts with 0 answers
sum(df["AnswerCount"]==0)
# Out:
# 2201947

# %% [markdown]
# # Conclusions

# %%
sum(df["Score"]>=5)
# Out:
# 1245633

# %%
sum(df["ViewCount"]>=50)
# Out:
# 13953454

# %% [markdown]
# # Ignored posts

# %%
# check ignored posts
ignored = df.loc[df["Score"]<5]
#ignored = ignored.loc[ignored["ViewCount"]<50]

# %%
ignored.describe()
# Out:
#               Score     ViewCount     WordCount    LinksCount   BlocksCount  \
# count  1.517402e+07  1.517402e+07  1.517402e+07  1.517402e+07  1.517402e+07
# mean   5.779883e-01  8.478276e+02  8.862121e+01  2.878702e-01  1.994759e+00
# std    1.280229e+00  2.244734e+03  6.230528e+01  6.853340e-01  1.968804e+00
# min   -1.850000e+02  1.000000e+00  2.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  7.000000e+01  4.800000e+01  0.000000e+00  1.000000e+00
# 50%    0.000000e+00  2.280000e+02  7.300000e+01  0.000000e+00  1.000000e+00
# 75%    1.000000e+00  7.440000e+02  1.110000e+02  0.000000e+00  3.000000e+00
# max    4.000000e+00  5.685940e+05  8.020000e+03  9.000000e+00  9.000000e+00
#
#        TitleWordsCount   AnswerCount  CommentCount  tagsAggregate
# count     1.517402e+07  1.517402e+07  1.517402e+07   1.517402e+07
# mean      8.584576e+00  1.397674e+00  1.962843e+00   9.558137e+05
# std       3.617856e+00  1.084636e+00  2.638895e+00   8.547101e+05
# min       1.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       6.000000e+00  1.000000e+00  0.000000e+00   1.709860e+05
# 50%       8.000000e+00  1.000000e+00  1.000000e+00   8.986940e+05
# 75%       1.100000e+01  2.000000e+00  3.000000e+00   1.487235e+06
# max       4.500000e+01  2.400000e+01  1.090000e+02   6.680300e+06

# %%
ignored.corr()
# Out:
#                     Score  ViewCount  WordCount  LinksCount  BlocksCount  \
# Score            1.000000   0.236557   0.092367    0.044439     0.054420
# ViewCount        0.236557   1.000000   0.001778   -0.012068    -0.010418
# WordCount        0.092367   0.001778   1.000000    0.173990     0.139482
# LinksCount       0.044439  -0.012068   0.173990    1.000000     0.021976
# BlocksCount      0.054420  -0.010418   0.139482    0.021976     1.000000
# TitleWordsCount -0.004778  -0.017935   0.080350    0.011184    -0.007098
# AnswerCount      0.117799   0.236360  -0.055836   -0.066120     0.014055
# CommentCount    -0.089796  -0.020600   0.050155    0.005562     0.104015
# bounty           0.093386   0.013627   0.046754    0.040522     0.020218
# tagsAggregate   -0.056637   0.005009   0.001594    0.012155     0.083808
# isAnswered       0.115877   0.097705  -0.015354   -0.010729     0.076243
#
#                  TitleWordsCount  AnswerCount  CommentCount    bounty  \
# Score                  -0.004778     0.117799     -0.089796  0.093386
# ViewCount              -0.017935     0.236360     -0.020600  0.013627
# WordCount               0.080350    -0.055836      0.050155  0.046754
# LinksCount              0.011184    -0.066120      0.005562  0.040522
# BlocksCount            -0.007098     0.014055      0.104015  0.020218
# TitleWordsCount         1.000000    -0.018475     -0.005667  0.003993
# AnswerCount            -0.018475     1.000000     -0.026159  0.039006
# CommentCount           -0.005667    -0.026159      1.000000  0.024639
# bounty                  0.003993     0.039006      0.024639  1.000000
# tagsAggregate           0.004040     0.103910      0.126208 -0.013980
# isAnswered             -0.015843     0.291720     -0.073857  0.012931
#
#                  tagsAggregate  isAnswered
# Score                -0.056637    0.115877
# ViewCount             0.005009    0.097705
# WordCount             0.001594   -0.015354
# LinksCount            0.012155   -0.010729
# BlocksCount           0.083808    0.076243
# TitleWordsCount       0.004040   -0.015843
# AnswerCount           0.103910    0.291720
# CommentCount          0.126208   -0.073857
# bounty               -0.013980    0.012931
# tagsAggregate         1.000000    0.032396
# isAnswered            0.032396    1.000000

# %%
#do not re-run this
plot = ggplot(ignored, aes(x="isAnswered"))
plot += geom_bar()
plot
# Out:
# <ggplot: (8765760103579)>

# %%
# how many ignored posts has 0 answers (proportion)
sum(ignored["AnswerCount"]==0)/ignored.shape[0]
# Out:
# 0.14384460124313786

# %% [markdown]
# # Not ignored posts

# %%
# remove ignored posts
df = df.loc[df["Score"]>=5]
#df = df.loc[df["ViewCount"]>=50]

# %%
df.describe()
# Out:
#               Score     ViewCount     WordCount    LinksCount   BlocksCount  \
# count  1.245633e+06  1.245633e+06  1.245633e+06  1.245633e+06  1.245633e+06
# mean   1.827287e+01  1.747344e+04  9.515758e+01  3.816983e-01  2.051096e+00
# std    9.348590e+01  4.928964e+04  7.749466e+01  8.616599e-01  2.163667e+00
# min    5.000000e+00  2.000000e+01  2.000000e+00  0.000000e+00  0.000000e+00
# 25%    6.000000e+00  1.660000e+03  4.700000e+01  0.000000e+00  0.000000e+00
# 50%    8.000000e+00  5.366000e+03  7.500000e+01  0.000000e+00  1.000000e+00
# 75%    1.500000e+01  1.537500e+04  1.190000e+02  0.000000e+00  3.000000e+00
# max    2.225200e+04  3.913031e+06  3.872000e+03  9.000000e+00  9.000000e+00
#
#        TitleWordsCount   AnswerCount  CommentCount  tagsAggregate
# count     1.245633e+06  1.245633e+06  1.245633e+06   1.245633e+06
# mean      8.472321e+00  3.223982e+00  2.047366e+00   8.644809e+05
# std       3.419727e+00  2.685434e+00  2.922575e+00   7.515952e+05
# min       1.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       6.000000e+00  1.000000e+00  0.000000e+00   1.538880e+05
# 50%       8.000000e+00  2.000000e+00  1.000000e+00   7.289210e+05
# 75%       1.000000e+01  4.000000e+00  3.000000e+00   1.358665e+06
# max       3.300000e+01  2.400000e+01  1.030000e+02   6.092013e+06

# %%
df.corr()
# Out:
#                     Score  ViewCount  WordCount  LinksCount  BlocksCount  \
# Score            1.000000   0.458405  -0.027779   -0.006297    -0.004842
# ViewCount        0.458405   1.000000  -0.092874   -0.047956    -0.021482
# WordCount       -0.027779  -0.092874   1.000000    0.276834     0.161852
# LinksCount      -0.006297  -0.047956   0.276834    1.000000     0.071534
# BlocksCount     -0.004842  -0.021482   0.161852    0.071534     1.000000
# TitleWordsCount  0.003016  -0.010995   0.087800    0.027627     0.011734
# AnswerCount      0.217173   0.417567  -0.052970   -0.060020    -0.084663
# CommentCount     0.034223  -0.001027   0.150844    0.086068     0.120190
# bounty           0.002540  -0.067309   0.156357    0.146776     0.078637
# tagsAggregate    0.009717   0.050396   0.008352    0.020171     0.067965
# isAnswered       0.033853   0.064940  -0.069918   -0.046313     0.026697
#
#                  TitleWordsCount  AnswerCount  CommentCount    bounty  \
# Score                   0.003016     0.217173      0.034223  0.002540
# ViewCount              -0.010995     0.417567     -0.001027 -0.067309
# WordCount               0.087800    -0.052970      0.150844  0.156357
# LinksCount              0.027627    -0.060020      0.086068  0.146776
# BlocksCount             0.011734    -0.084663      0.120190  0.078637
# TitleWordsCount         1.000000    -0.007280      0.014439  0.031753
# AnswerCount            -0.007280     1.000000      0.061989 -0.043851
# CommentCount            0.014439     0.061989      1.000000  0.160900
# bounty                  0.031753    -0.043851      0.160900  1.000000
# tagsAggregate          -0.010899     0.069566      0.099978  0.030611
# isAnswered             -0.009840     0.081357     -0.088118 -0.144562
#
#                  tagsAggregate  isAnswered
# Score                 0.009717    0.033853
# ViewCount             0.050396    0.064940
# WordCount             0.008352   -0.069918
# LinksCount            0.020171   -0.046313
# BlocksCount           0.067965    0.026697
# TitleWordsCount      -0.010899   -0.009840
# AnswerCount           0.069566    0.081357
# CommentCount          0.099978   -0.088118
# bounty                0.030611   -0.144562
# tagsAggregate         1.000000    0.025622
# isAnswered            0.025622    1.000000

# %%
# how many ignored posts has 0 answers (proportion)
sum(df["AnswerCount"]==0)/df.shape[0]
# Out:
# 0.015450778840958773

# %%
temp_df = df.sample(n=10000)

# %%
#do not re-run this
plot = ggplot(df, aes(x="isAnswered"))
plot += geom_bar()
plot
# Out:
# <ggplot: (8765759996578)>

# %%
plot = ggplot(temp_df, aes(x="Score", y="ViewCount", color="isAnswered"))
#plot += xlim(-5,10)
#plot += ylim(0,10000)
plot += geom_jitter(size=0.1)
plot += scale_y_log10()
plot
# Out:
# <ggplot: (8765759996480)>

# %%
plot = ggplot(temp_df, aes(x="Score", y="AnswerCount", color="isAnswered"))
plot += geom_jitter(size=0.1)
plot
# Out:
# <ggplot: (8765747878134)>
