# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
from plotnine import *

# %%
#posts = dd.read_csv("Complete-Posts-Compressed/*.tar.xz", compression="xz")
posts = dd.read_csv("Complete-Posts/*.csv")

# %%
posts.astype(float).corr().compute()["isAnswered"]
# Out:
# /home/wojtek/.local/lib/python3.6/site-packages/pandas/core/frame.py:7152: RuntimeWarning: Degrees of freedom <= 0 for slice
#   baseCov = np.cov(mat.T)
# /usr/lib64/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)
# /usr/lib64/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: invalid value encountered in multiply
#   c *= 1. / np.float64(fact)
# Score              0.032817
# ViewCount          0.058519
# WordCount         -0.011782
# LinksCount        -0.007131
# BlocksCount        0.062507
# TitleWordsCount   -0.015539
# AnswerCount        0.255678
# CommentCount      -0.071210
# bounty             0.009829
# tagsAggregate      0.027496
# isAnswered         1.000000
# Name: isAnswered, dtype: float64

# %%
posts.astype(float).describe().compute()
# Out:
#               Score     ViewCount     WordCount    LinksCount   BlocksCount  \
# count  1.691468e+07  1.691468e+07  1.691468e+07  1.691468e+07  1.691468e+07
# mean   2.035817e+00  2.162654e+03  9.153142e+01  3.060061e-01  2.339642e+00
# std    3.041040e+01  1.711538e+04  6.692279e+01  7.574304e-01  2.924335e+00
# min   -1.850000e+02  1.000000e+00  2.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  1.510000e+02  5.100000e+01  0.000000e+00  1.000000e+00
# 50%    1.000000e+00  5.150000e+02  9.100000e+01  0.000000e+00  2.000000e+00
# 75%    2.610000e+02  1.679900e+04  1.220000e+02  1.000000e+00  3.000000e+00
# max    2.225200e+04  7.256499e+06  8.020000e+03  1.630000e+02  3.690000e+02
#
#        TitleWordsCount   AnswerCount  CommentCount        bounty  \
# count     1.691468e+07  1.691468e+07  1.691468e+07  1.691468e+07
# mean      8.588983e+00  1.540255e+00  1.991912e+00  1.488441e-02
# std       3.605612e+00  1.447826e+00  2.697285e+00  1.210903e-01
# min       1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%       7.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 50%       9.000000e+00  2.000000e+00  2.000000e+00  0.000000e+00
# 75%       1.200000e+01  6.000000e+00  3.000000e+00  0.000000e+00
# max       4.500000e+01  5.180000e+02  1.090000e+02  1.000000e+00
#
#        tagsAggregate    isAnswered
# count   1.691468e+07  1.691468e+07
# mean    9.482382e+05  5.287340e-01
# std     8.460248e+05  4.991737e-01
# min     0.000000e+00  0.000000e+00
# 25%     2.560540e+05  0.000000e+00
# 50%     1.088185e+06  1.000000e+00
# 75%     1.524036e+06  1.000000e+00
# max     6.680300e+06  1.000000e+00

# %%
df = posts.compute()

# %%
df.head()
# Out:
#    Score  ViewCount  WordCount  LinksCount  BlocksCount  TitleWordsCount  \
# 0    261      16799         91           1            3               12
# 0   1743     500536         15           0            1                8
# 1   1382     139190         21           0            1                5
# 2    552     160858         32           0            1                4
# 3    381     111934          9           2            2                5
#
#    AnswerCount  CommentCount  bounty  tagsAggregate  isAnswered
# 0            6             0   False        1434581        True
# 0           63             7    True        1587941        True
# 1           35             3   False        1333380        True
# 2           24             8   False         820908       False
# 3           10             4    True         308305       False

# %%
# plot random sample of 1000 points 
temp_df = df.sample(n=1000)
for column in posts.compute():
    if column != "isAnswered":
        print(column)
        plot = ggplot(temp_df, aes(x="isAnswered", y=column))
        plot += geom_jitter()
        print(plot)
# Out:
# Score
# <ggplot: (-9223363242915711961)>
# ViewCount
# <ggplot: (8793939038065)>
# WordCount
# <ggplot: (8793938997575)>
# LinksCount
# <ggplot: (-9223363242916030292)>
# BlocksCount
# <ggplot: (-9223363242915697264)>
# TitleWordsCount
# <ggplot: (8793938795440)>
# AnswerCount
# <ggplot: (8793938884307)>
# CommentCount
# <ggplot: (8793930840072)>
# bounty
# <ggplot: (-9223363242923945724)>
# tagsAggregate
# <ggplot: (-9223363242915867725)>

# %%
# TODO caluclate number of posts with 0 answers
