# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np

# %%
#posts = dd.read_csv("Complete-Posts-Compressed/*.tar.xz", compression="xz")
posts = dd.read_csv("Complete-Posts/*.csv")

# %%
posts.astype(float).corr().compute()
# Out:
# /usr/lib64/python3.6/site-packages/pandas/core/frame.py:5550: RuntimeWarning: Degrees of freedom <= 0 for slice
#   baseCov = np.cov(mat.T)
# /usr/lib64/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)
# /usr/lib64/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: invalid value encountered in multiply
#   c *= 1. / np.float64(fact)
#                     Score  ViewCount  WordCount  LinksCount  BlocksCount  \
# Score            1.000000   0.577167   0.001391    0.011142     0.004497
# ViewCount        0.577167   1.000000  -0.018125   -0.002054    -0.006090
# WordCount        0.001391  -0.018125   1.000000    0.208272     0.260046
# LinksCount       0.011142  -0.002054   0.208272    1.000000     0.070794
# BlocksCount      0.004497  -0.006090   0.260046    0.070794     1.000000
# TitleWordsCount -0.000711  -0.006467   0.083224    0.014888     0.012670
# AnswerCount      0.227273   0.370084  -0.035118   -0.033123    -0.005095
# CommentCount     0.013444   0.004347   0.072458    0.020353     0.104160
# bounty           0.039613   0.018050   0.084041    0.074357     0.053388
# tagsAggregate   -0.004158   0.004011  -0.000527    0.009334     0.049931
# isAnswered       0.032817   0.058519  -0.011782   -0.007131     0.062507
#
#                  TitleWordsCount  AnswerCount  CommentCount    bounty  \
# Score                  -0.000711     0.227273      0.013444  0.039613
# ViewCount              -0.006467     0.370084      0.004347  0.018050
# WordCount               0.083224    -0.035118      0.072458  0.084041
# LinksCount              0.014888    -0.033123      0.020353  0.074357
# BlocksCount             0.012670    -0.005095      0.104160  0.053388
# TitleWordsCount         1.000000    -0.016539     -0.003193  0.007666
# AnswerCount            -0.016539     1.000000      0.001690  0.072226
# CommentCount           -0.003193     0.001690      1.000000  0.057297
# bounty                  0.007666     0.072226      0.057297  1.000000
# tagsAggregate           0.003078     0.071079      0.121405 -0.009486
# isAnswered             -0.015539     0.255678     -0.071210  0.009829
#
#                  tagsAggregate  isAnswered
# Score                -0.004158    0.032817
# ViewCount             0.004011    0.058519
# WordCount            -0.000527   -0.011782
# LinksCount            0.009334   -0.007131
# BlocksCount           0.049931    0.062507
# TitleWordsCount       0.003078   -0.015539
# AnswerCount           0.071079    0.255678
# CommentCount          0.121405   -0.071210
# bounty               -0.009486    0.009829
# tagsAggregate         1.000000    0.027496
# isAnswered            0.027496    1.000000
